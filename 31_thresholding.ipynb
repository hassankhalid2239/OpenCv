# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img=cv2.imread("images\\img13.png")
img=cv2.resize(img,(600,400))
img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# _,th=cv2.threshold(img,190,255,cv2.THRESH_BINARY)
# _,th=cv2.threshold(img,190,255,cv2.THRESH_BINARY_INV)
# _,th=cv2.threshold(img,190,255,cv2.THRESH_MASK)
_,th=cv2.threshold(img,190,255,cv2.THRESH_TRIANGLE)

cv2.imshow("Window",img)
cv2.imshow("Window1",th)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img=cv2.imread("images\\img13.png")
img=cv2.resize(img,(600,400))
img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

_,th=cv2.threshold(img,190,255,cv2.THRESH_TRIANGLE)
thresh=cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,11,2)
cv2.imshow("Binary Thresh",img)
cv2.imshow("Adaptive Thresh",img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img=cv2.imread("images\\img14.png")
img=cv2.resize(img,(600,400))
img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# _,th=cv2.threshold(img,190,255,cv2.THRESH_BINARY)
# _,th=cv2.threshold(img,190,255,cv2.THRESH_BINARY_INV)
# _,th=cv2.threshold(img,190,255,cv2.THRESH_MASK)
_,th=cv2.threshold(img,190,255,cv2.THRESH_TRIANGLE)

cv2.imshow("Window",img)
cv2.imshow("Window1",th)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img=cv2.imread("images\\img16.png")
img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

hist=cv2.calcHist([img],[0],None,[255],[0,255])

plt.plot(hist)
plt.show()

_,th=cv2.threshold(img,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)


cv2.imshow("Window",img)
cv2.imshow("Window1",th)
cv2.waitKey(0)
cv2.destroyAllWindows()
